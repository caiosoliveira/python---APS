# %%
# Célula 1 — imports
import sys
sys.path.insert(0, '..')  # aponta para a pasta do projecto

from response_engine import ResponseEngine

# %%
# Célula 2 — carregar o motor
engine = ResponseEngine(responses_path="../responses.json")
# Out:
# ...
# Loading weights:   0%|          | 0/199 [00:00<?, ?it/s]
# BertModel LOAD REPORT from: sentence-transformers/paraphrase-multilingual-MiniLM-L12-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Motor carregado: 15 pares de resposta.

# %%
# Célula 3 — testar com várias perguntas (zero créditos API)
testes = [
    "A que horas abrem?",
    "Como faço para marcar?",
    "Fica perto do metro?",
    "Quanto custa?",
    "Têm parking?",
    "Que tempo vai fazer amanhã?",   # deve cair no fallback
    "Quero saber do estacionamento",
]

for pergunta in testes:
    print(f"\n→ '{pergunta}'")
    resposta = engine.get_response(pergunta)
    print(f"  {resposta}")
# Out:
# → 'A que horas abrem?'
# Match: 'Qual é o horário de atendimento?' (score: 0.67)
#   Estamos abertos de segunda a sexta, das oito às vinte horas, e ao sábado das nove às treze horas.
#
# → 'Como faço para marcar?'
# Match: 'Como faço para marcar?' (score: 1.00)
#   Pode marcar consulta pelo telefone, ou através do nosso site oficial.
#
# → 'Fica perto do metro?'
# Match: 'Ficam perto do metro?' (score: 0.98)
#   Estamos situados no centro da cidade, perto do metro. Pode consultar a morada no nosso site.
#
# → 'Quanto custa?'
# Match: 'Qual é o custo de uma consulta?' (score: 0.58)
#   O preço de consulta geral é de cinquenta euros. Especialidades podem ter custo diferente.
#
# → 'Têm parking?'
# Match: 'Têm estacionamento disponível?' (score: 0.89)
#   Sim, dispomos de estacionamento gratuito para clientes nas traseiras do edifício.
#
# → 'Que tempo vai fazer amanhã?'
# Match: 'Qual é o horário de atendimento?' (score: 0.51)
# ...

# %%
# Debug — confirmar pares carregados
for i, p in enumerate(engine.pairs):
    print(f"{i:2}. {p['question']}")
# Out:
#  0. Qual é o horário de atendimento?
#  1. Como posso marcar uma consulta?
#  2. Aceitam seguro de saúde?
#  3. Onde ficam localizados?
#  4. Qual é o custo de uma consulta?
#  5. Têm estacionamento disponível?
#  6. Quanto tempo dura uma consulta?
#  7. Podem enviar os resultados por email?
#  8. Como chego às vossas instalações?
#  9. Ficam perto do metro?
# 10. Como faço para marcar uma consulta?
# 11. Não tenho informação sobre esse assunto
# 12. Como marco uma consulta?
# 13. Quero marcar uma consulta
# 14. Como faço para marcar?
