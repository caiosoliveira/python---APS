# %%
# Célula 1 — imports e teste de gravação curta
import sys
sys.path.insert(0, '..')  # para encontrar os módulos na pasta pai

from audio_input import record_audio, load_audio_file
import IPython.display as ipd

# Teste 1: gravar 3 segundos
#path = record_audio(duration_seconds=3)
#ipd.Audio(path)

# %%
# Célula 2 — teste de carregar ficheiro
# Coloca qualquer .wav na pasta samples/ para testar
# path = load_audio_file("../samples/teste.wav")
# ipd.Audio(path)
print("Módulo audio_input importado com sucesso.")
# Out:
# Módulo audio_input importado com sucesso.

# %%
# Cola isto num notebook qualquer e corre
from audio_input import record_audio

path = record_audio(duration_seconds=5)
print(f"Ficheiro gravado em: {path}")
# Out:
# A gravar 5s... fala agora!
# Gravação concluída.
# Ficheiro gravado em: C:\Users\Caio\AppData\Local\Temp\tmp2p9p1viw.wav

# %%
from audio_input import record_audio

path = record_audio(duration_seconds=90)
print(f"Guardado em: {path}")
# Out:
# A gravar 90s... fala agora!
# Gravação concluída.
# Guardado em: C:\Users\Caio\AppData\Local\Temp\tmpzmmxkuth.wav
